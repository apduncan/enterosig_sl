# %%
from enterosig.denovo import rank_selection, decompositions, plot_rank_selection
import pandas as pd
import logging

# %% [markdown]
# ## Read Crohns Atlas data

# %%
gca = pd.read_csv("/Users/pez23lof/Documents/cellgen/gut_cell_atlas/crohns_cell_tables/count.tsv",
                  index_col=0,
                  sep="\t")
print(gca.shape)
gca.head()
# Out:
# (67, 225)
#                                        H101694_E  H101694_L  H102141_E  \
# Celltype
# Activated fibroblasts CCL19 ADAMADEC1        0.0        1.0        0.0
# B cells                                      0.0      145.0        1.0
# B cells AICDA LRMP                           0.0       15.0        0.0
# Cycling cells                                2.0       20.0        1.0
# DC1                                          0.0        4.0        0.0
#
#                                        H102141_L  H106265_N  H110216_E  \
# Celltype
# Activated fibroblasts CCL19 ADAMADEC1        3.0        2.0        0.0
# B cells                                    387.0       11.0        1.0
# B cells AICDA LRMP                          10.0        0.0        1.0
# Cycling cells                               27.0        0.0        2.0
# DC1                                          5.0       10.0        0.0
#
#                                        H110216_L  H139073_N  H152638_L  \
# Celltype
# Activated fibroblasts CCL19 ADAMADEC1        0.0        6.0       11.0
# B cells                                     21.0       43.0      550.0
# B cells AICDA LRMP                           0.0        0.0       50.0
# Cycling cells                                5.0        0.0       54.0
# DC1                                         21.0       11.0        9.0
#
#                                        H157844_E  ...  N46_LP_A  N46_LP_B  \
# Celltype                                          ...
# Activated fibroblasts CCL19 ADAMADEC1        0.0  ...      11.0       3.0
# B cells                                      0.0  ...      94.0      29.0
# B cells AICDA LRMP                           0.0  ...       0.0       0.0
# Cycling cells                                0.0  ...       0.0       0.0
# DC1                                          0.0  ...      26.0      34.0
#
#                                        N51_Epi_A  N51_Epi_B  N51_LP_A  \
# Celltype
# Activated fibroblasts CCL19 ADAMADEC1        0.0        0.0      22.0
# B cells                                      2.0        0.0    1857.0
# B cells AICDA LRMP                           0.0        0.0     122.0
# Cycling cells                                0.0        0.0       0.0
# DC1                                          0.0        0.0       9.0
#
#                                        N51_LP_B  N8_Epi_A  N8_Epi_B  N8_LP_A  \
# Celltype
# Activated fibroblasts CCL19 ADAMADEC1      21.0       0.0       0.0      1.0
# B cells                                    44.0       0.0       0.0     10.0
# B cells AICDA LRMP                          0.0       0.0       0.0      0.0
# Cycling cells                               0.0       0.0       0.0      0.0
# DC1                                        14.0       0.0       0.0      2.0
#
#                                        N8_LP_B
# Celltype
# Activated fibroblasts CCL19 ADAMADEC1      6.0
# B cells                                    1.0
# B cells AICDA LRMP                         0.0
# Cycling cells                              0.0
# DC1                                        5.0
#
# [5 rows x 225 columns]

# %%
gca_meta = pd.read_csv("/Users/pez23lof/Documents/cellgen/gut_cell_atlas/crohns_cell_tables/sample_metadata.tsv",
                       sep="\t",
                       index_col=0)
# Reorder to match cell table ordering
gca_meta = gca_meta.loc[gca.columns]
gca_meta.head()
assert gca_meta.shape[0] == gca.shape[1], "Data and metadata dimensions do not match"

# %% [markdown]
# ## Rank Selection

# %%
rank_sel_results = rank_selection(x=gca / gca.sum(),
                                  ranks=list(range(2, 20)),
                                  shuffles=100,
                                  seed=4298)
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 1800/1800 [05:50<00:00,  5.13it/s]

# %%
plt_f = plot_rank_selection(
    rank_sel_results,
    jitter=False,
    n_col=2, exclude=['l2_norm', 'sparsity_h', 'sparsity_w']
).draw()
plt_f.set_size_inches(8, 6)
plt_f

# %% [markdown]
# ## Examine decompositions

# %%
decomps = decompositions(
    x=gca,
    ranks=[6, 7, 8],
    random_starts=20,
    seed=4298
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 64.94it/s]

# %%
best_decomp = decomps[6][0]

# %%
best_decomp.plot_modelfit(gca_meta['site'])
# Out:
# <Figure Size: (640 x 480)>

# %%
plt_ra = best_decomp.plot_relative_weight(group=gca_meta['organ__ontology_label'])
plt_ra

# %%
best_decomp.plot_pcoa()
# Out:
# <Figure Size: (640 x 480)>

# %%
best_decomp.representative_signatures(threshold=0.9)
# Out:
#     H101694_E  H101694_L  H102141_E  H102141_L  H106265_N  H110216_E  \
# S1      False       True      False       True      False      False
# S2      False      False      False      False       True      False
# S3      False       True      False       True      False      False
# S4       True       True      False       True      False       True
# S5      False      False      False      False       True      False
# S6       True       True       True       True      False       True
#
#     H110216_L  H139073_N  H152638_L  H157844_E  ...  N46_LP_A  N46_LP_B  \
# S1      False      False       True      False  ...     False     False
# S2      False       True      False      False  ...     False     False
# S3       True       True      False      False  ...      True      True
# S4       True      False       True       True  ...     False      True
# S5      False      False      False      False  ...     False     False
# S6      False      False       True       True  ...     False     False
#
#     N51_Epi_A  N51_Epi_B  N51_LP_A  N51_LP_B  N8_Epi_A  N8_Epi_B  N8_LP_A  \
# S1      False      False      True     False     False     False    False
# S2       True       True     False     False      True      True    False
# S3      False      False      True      True     False     False     True
# S4      False      False     False     False     False     False    False
# S5      False      False     False     False     False     False     True
# S6      False      False     False     False     False     False    False
#
#     N8_LP_B
# S1    False
# S2    False
# S3     True
# S4    False
# S5     True
# S6    False
#
# [6 rows x 225 columns]

# %%
best_decomp.monodominant_samples(threshold=0.9)
# Out:
#            is_monodominant signature_name
# H101694_E            False            NaN
# H101694_L            False            NaN
# H102141_E             True             S6
# H102141_L            False            NaN
# H106265_N            False            NaN
# ...                    ...            ...
# N51_LP_B              True             S3
# N8_Epi_A              True             S2
# N8_Epi_B              True             S2
# N8_LP_A              False            NaN
# N8_LP_B              False            NaN
#
# [225 rows x 2 columns]
